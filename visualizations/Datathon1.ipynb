# %%
import pandas as pd 
import numpy as np 
from io import StringIO
import requests



pd.set_option('display.max_columns', None)
url='https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/totals/co-est2019-alldata.csv'
s=requests.get(url).text

data1 = pd.read_csv(StringIO(s))



    
url1='https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/state/detail/SCPRC-EST2019-18+POP-RES.csv?#'
s1 = requests.get(url1).text
data2 = pd.read_csv(StringIO(s1))

# %%
# %pwd
# Out:
# '/Users/garbamoussa/Desktop/Python_ML/Datathon_MIT'

# %%
# %cd /Users/garbamoussa/Desktop/Python_ML/Datathon_MIT
# Out:
# /Users/garbamoussa/Desktop/Python_ML/Datathon_MIT

# %%
data1.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0        4779736            4780125          4785437          4799069
# 1          54571              54597            54773            55227
# 2         182265             182265           183112           186558
# 3          27457              27455            27327            27341
# 4          22915              22915            22870            22745
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# ...

# %%
data2.head()
# Out:
#    SUMLEV REGION DIVISION  STATE           NAME  POPESTIMATE2019  \
# 0      10      0        0      0  United States        328239523
# 1      40      3        6      1        Alabama          4903185
# 2      40      4        9      2         Alaska           731545
# 3      40      4        8      4        Arizona          7278717
# 4      40      3        7      5       Arkansas          3017804
#
#    POPEST18PLUS2019  PCNT_POPEST18PLUS
# 0         255200373               77.7
# 1           3814879               77.8
# 2            551562               75.4
# 3           5638481               77.5
# 4           2317649               76.8

# %%
#County_level_pop.head()

# %%
data1.shape
# Out:
# (3193, 164)

# %% [markdown]
# 'SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME','POPESTIMATE2019'
# {'NPOPCHG_2019', 'BIRTHS2019', 'DEATHS2019', 'NATURALINC2019', 'INTERNATIONALMIG2019', 'DOMESTICMIG2019''NETMIG2019', 'RESIDUAL2019', 'GQESTIMATES2019',
# 'RDEATH2019', 'RNATURALINC2019', 'RINTERNATIONALMIG2019', 'RNETMIG2019'}

# %%
County_level_pop = data1[['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME','POPESTIMATE2019']]

# %%
County_level_pop.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    POPESTIMATE2019
# 0          4903185
# 1            55869
# 2           223234
# 3            24686
# 4            22394

# %%
STNAME_STATE = County_level_pop[['STNAME','STATE']]

# %%
County_level_pop.shape
# Out:
# (3193, 8)

# %%
County_level_pop.to_csv('County_level_total.csv', index=False, sep=',')

# %%
#%cd /Users/garbamoussa/Desktop/Python_ML/Datathon_MIT/safegraph_open_census_data

# %%
# %ls
# Out:
# data/     geometry/ metadata/

# %%
#%cd safegraph_open_census_data/

# %%
# %ls
# Out:
# data/     geometry/ metadata/

# %%
# %cd /Users/garbamoussa/Desktop/Python_ML/Datathon_MIT/safegraph_open_census_data/data
# Out:
# /Users/garbamoussa/Desktop/Python_ML/Datathon_MIT/safegraph_open_census_data/data

# %%
# %ls
# Out:
# cbg_b00.csv       cbg_b09.csv       cbg_b20.csv       cbg_b99.csv
# cbg_b01.csv       cbg_b11.csv       cbg_b21.csv       cbg_c16.csv
# cbg_b02.csv       cbg_b12.csv       cbg_b22.csv       cbg_c17.csv
# cbg_b03.csv       cbg_b14.csv       cbg_b23.csv       cbg_c24.csv
# cbg_b07.csv       cbg_b15.csv       cbg_b25.csv       cbg_patterns.csv
# cbg_b08.csv       cbg_b19.csv       cbg_b27.csv

# %%
cbg_b00 = pd.read_csv('cbg_b00.csv')

cbg_b27  = pd.read_csv('cbg_b27.csv')
cbg_patterns  = pd.read_csv('cbg_patterns.csv')

# %%
# %cd ..
# Out:
# /Users/garbamoussa/Desktop/Python_ML/Datathon_MIT/safegraph_open_census_data

# %%
# %ls
# Out:
# data/     geometry/ metadata/

# %%
# %cd metadata
# Out:
# /Users/garbamoussa/Desktop/Python_ML/Datathon_MIT/safegraph_open_census_data/metadata

# %%
# %ls
# Out:
# County_level_total.csv
# Datathon.ipynb
# Datathon1.ipynb
# Safegraph-Starbucks-Demo - Databricks.html
# data_county_age_race.csv
# safegraph_open_census_data/
# uscities.csv*
# uszips.csv*

# %%
import pandas as pd 
pd.set_option('display.max_columns', None)
uscities   = pd.read_csv('uscities.csv')
uszips    = pd.read_csv('uszips.csv')
data_county_age_race   = pd.read_csv('data_county_age_race.csv')
data_county_age_race['state'] = data_county_age_race['geo_id'] // np.power(10, np.log10(data_county_age_race['geo_id']).astype(int) - 1)

# %%
County_pop = data_county_age_race[['geo_id','state', 'total_pop', 'households', 'male_pop', 'female_pop', 'median_age', 'male_65_to_66', 'male_67_to_69', 
'male_70_to_74', 'male_75_to_79', 'male_85_and_over',  'female_65_to_66', 'female_67_to_69', 'female_70_to_74', 'female_75_to_79',
'female_80_to_84', 'female_85_and_over', 'white_pop', 'not_us_citizen_pop', 'black_pop', 'asian_pop', 'hispanic_pop', 'amerindian_pop', 'other_race_pop', 
'median_income', 'income_per_capita', 'income_less_10000', 'income_50000_59999', 'income_100000_124999', 'income_200000_or_more', 'poverty', 'gini_index', 
'nonfamily_households', 'family_households','male_male_households', 'female_female_households','high_school_diploma', 'masters_degree', 'less_one_year_college',
'one_year_more_college', 'employed_education_health_social', 'speak_only_english_at_home']]

# %%
County_pop
# Out:
#       geo_id  state  total_pop  households  male_pop  female_pop  median_age  \
# 0      35039     35      39307       12398     19250       20057        40.6
# 1      72001     72      18181        5861      8862        9319        40.9
# 2      72049     72       1314         475       676         638        42.8
# 3      72147     72       8771        2470      4332        4439        43.6
# 4      72071     72      42420       15012     20629       21791        41.6
# ...      ...    ...        ...         ...       ...         ...         ...
# 3215    8031     80     693417      294358    347188      346229        34.4
# 3216   34017     34     668631      255429    332268      336363        35.1
# 3217   24510     24     614700      238436    288691      326009        35.1
# 3218   12086     12    2715516      870051   1318627     1396889        39.7
# 3219   36047     36    2600747      950856   1231912     1368835        35.1
#
# ...

# %%
County_pop.to_csv('County_pop.csv', index=False, sep=',')

# %%
uscities.shape
# Out:
# (28889, 19)

# %%
uszips.head(3)
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18004 -66.75218   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36073 -67.17517     Aguada       PR  Puerto Rico  True
# 2  603  18.45439 -67.12202  Aguadilla       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN       17242    111.4        72001    Adjuntas
# 1          NaN       38442    523.5        72003      Aguada
# 2          NaN       48814    667.9        72005   Aguadilla
#
#                  county_weights county_names_all county_fips_all  imprecise  \
# 0  {'72001':99.43,'72141':0.57}  Adjuntas|Utuado     72001|72141      False
# 1                 {'72003':100}           Aguada           72003      False
# 2                 {'72005':100}        Aguadilla           72005      False
#
#    military             timezone
# 0     False  America/Puerto_Rico
# 1     False  America/Puerto_Rico
# 2     False  America/Puerto_Rico

# %%
data_county_age_race.head(3)
# Out:
#    geo_id     do_date  total_pop  households  male_pop  female_pop  \
# 0   35039  2014-01-01      39307       12398     19250       20057
# 1   72001  2014-01-01      18181        5861      8862        9319
# 2   72049  2014-01-01       1314         475       676         638
#
#    median_age  male_under_5  male_5_to_9  male_10_to_14  male_15_to_17  \
# 0        40.6          1224         1240           1278            846
# 1        40.9           443          479            659            388
# 2        42.8            38           48             41             28
#
#    male_18_to_19  male_20  male_21  male_22_to_24  male_25_to_29  \
# 0            488      381      182            602           1172
# 1            183       92      106            509            583
# 2             10        0        0             22             60
#
#    male_30_to_34  male_35_to_39  male_40_to_44  male_45_to_49  male_50_to_54  \
# ...

# %%
['geo_id','state', 'total_pop', 'households', 'male_pop', 'female_pop', 'median_age', 'male_65_to_66', 'male_67_to_69', 
'male_70_to_74', 'male_75_to_79', 'male_85_and_over',  'female_65_to_66', 'female_67_to_69', 'female_70_to_74', 'female_75_to_79',
'female_80_to_84', 'female_85_and_over', 'white_pop', 'not_us_citizen_pop', 'black_pop', 'asian_pop', 'hispanic_pop', 'amerindian_pop', 'other_race_pop', 
'median_income', 'income_per_capita', 'income_less_10000', 'income_50000_59999', 'income_100000_124999', 'income_200000_or_more', 'poverty', 'gini_index', 
'nonfamily_households', 'family_households','male_male_households', 'female_female_households','high_school_diploma', 'masters_degree', 'less_one_year_college',
'one_year_more_college', 'employed_education_health_social', 'speak_only_english_at_home']
# Out:
# ['geo_id',
#  'state',
#  'total_pop',
#  'households',
#  'male_pop',
#  'female_pop',
#  'median_age',
#  'male_65_to_66',
#  'male_67_to_69',
#  'male_70_to_74',
#  'male_75_to_79',
#  'male_85_and_over',
#  'female_65_to_66',
#  'female_67_to_69',
#  'female_70_to_74',
#  'female_75_to_79',
#  'female_80_to_84',
#  'female_85_and_over',
#  'white_pop',
#  'not_us_citizen_pop',
#  'black_pop',
#  'asian_pop',
#  'hispanic_pop',
#  'amerindian_pop',
#  'other_race_pop',
#  'median_income',
#  'income_per_capita',
#  'income_less_10000',
#  'income_50000_59999',
#  'income_100000_124999',
#  'income_200000_or_more',
#  'poverty',
#  'gini_index',
#  'nonfamily_households',
#  'family_households',
#  'male_male_households',
#  'female_female_households',
#  'high_school_diploma',
#  'masters_degree',
#  'less_one_year_college',
#  'one_year_more_college',
#  'employed_education_health_social',
#  'speak_only_english_at_home']

# %% [markdown]
#  The geo_id column is a combination of the state and county FIPs codes.
#          The first two digits are the state.
#          The last three digits are the county.

# %%
data_county_age_race['state'] = data_county_age_race['geo_id'] // np.power(10, np.log10(data_county_age_race['geo_id']).astype(int) - 1)

# %%
data_county_age_race.head()
# Out:
#    geo_id     do_date  total_pop  households  male_pop  female_pop  \
# 0   35039  2014-01-01      39307       12398     19250       20057
# 1   72001  2014-01-01      18181        5861      8862        9319
# 2   72049  2014-01-01       1314         475       676         638
# 3   72147  2014-01-01       8771        2470      4332        4439
# 4   72071  2014-01-01      42420       15012     20629       21791
#
#    median_age  male_under_5  male_5_to_9  male_10_to_14  male_15_to_17  \
# 0        40.6          1224         1240           1278            846
# 1        40.9           443          479            659            388
# 2        42.8            38           48             41             28
# 3        43.6           288          274            219             64
# 4        41.6           898         1159           1381            877
#
#    male_18_to_19  male_20  male_21  male_22_to_24  male_25_to_29  \
# 0            488      381      182            602           1172
# ...

# %%
#data_county_age_race['county'] = data_county_age_race['geo_id'].astype(str).str[:-3].astype(np.int64)
#data_county_age_race['county'] = data_county_age_race.apply(lambda x: x['geo_id'][:-3])
#data_county_age_race['county'] = [x[:-4] for x in data_county_age_race['geo_id']]

data_county_age_race['county'] = data_county_age_race['geo_id'][:3]

# %%
data_county_age_race.head()
# Out:
#    geo_id     do_date  total_pop  households  male_pop  female_pop  \
# 0   35039  2014-01-01      39307       12398     19250       20057
# 1   72001  2014-01-01      18181        5861      8862        9319
# 2   72049  2014-01-01       1314         475       676         638
# 3   72147  2014-01-01       8771        2470      4332        4439
# 4   72071  2014-01-01      42420       15012     20629       21791
#
#    median_age  male_under_5  male_5_to_9  male_10_to_14  male_15_to_17  \
# 0        40.6          1224         1240           1278            846
# 1        40.9           443          479            659            388
# 2        42.8            38           48             41             28
# 3        43.6           288          274            219             64
# 4        41.6           898         1159           1381            877
#
#    male_18_to_19  male_20  male_21  male_22_to_24  male_25_to_29  \
# 0            488      381      182            602           1172
# ...

# %%
data_county_age_race.shape
# Out:
# (3220, 241)

# %%
# %ls
# Out:
# County_level_total.csv
# County_pop.csv
# Datathon.ipynb
# Datathon1.ipynb
# Safegraph-Starbucks-Demo - Databricks.html
# data_county_age_race.csv
# safegraph_open_census_data/
# uscities.csv*
# uszips.csv*
# weekly-patterns-4-26-2020-CT.csv
# weekly-patterns-4-26-2020-NH.csv
# weekly-patterns-4-26-2020-RI.csv

# %%
weekly_patterns_CT = pd.read_csv('weekly-patterns-4-26-2020-CT.csv')

weekly_patterns_NH  = pd.read_csv('weekly-patterns-4-26-2020-NH.csv')
weekly_patterns_RI = pd.read_csv('weekly-patterns-4-26-2020-RI.csv')

# %%
weekly_patterns_CT.head()
# Out:
#    Unnamed: 0                   safegraph_place_id  \
# 0         110  sg:03cf51aca5424a50add1aa9f026cbc06
# 1         119  sg:042412fca26944bebde7b45b661a89c0
# 2         169  sg:053d8cb61f784841b6af19b26b3c224c
# 3         193  sg:063ae966c79145789c2bcdb8948b0b3e
# 4         248  sg:07b288bc9c154054bdf7f42d50c4f115
#
#                        location_name region  postal_code  naics_code  \
# 0                              Mobil     CT         6810    447110.0
# 1                     Barney Library     CT         6032    519120.0
# 2                       Pops Exhaust     CT         6042    811111.0
# 3  Hartford HealthCare Medical Group     CT         6790    621111.0
# 4      Living Faith Christian Church     CT         6702    813110.0
#
#    raw_visit_counts  median_dwell  \
# 0                22          10.5
# 1                 6         120.5
# 2                 3          32.0
# 3                 5          59.0
# 4                 2          28.5
#
# ...

# %%
weekly_patterns_CT.shape
# Out:
# (39800, 16)

# %%
weekly_patterns_NH.head()
# Out:
#    Unnamed: 0                   safegraph_place_id  \
# 0          26  sg:00f6792e8a084dd7965b54d3793f4147
# 1         400  sg:0c68fa3725874bfd9a28fa0fbff44e45
# 2        1040  sg:21520b57122c4be3bd2bab33c06bc2c8
# 3        2240  sg:48d5e48447a04006989acd98fd020df0
# 4        2965  sg:6093b45eaa564ab680b9df1fbdb5a0a1
#
#                  location_name region  postal_code  naics_code  \
# 0                Dragon Palace     NH         3465    722511.0
# 1                  Aroma Joe's     NH         3867    722511.0
# 2               Cristy's Pizza     NH         3842    722511.0
# 3  St Nicholas Orthodox Church     NH         3104    813110.0
# 4               Tire Warehouse     NH         3833    441310.0
#
#    raw_visit_counts  median_dwell  \
# 0                 5          12.0
# 1                65           7.0
# 2                28          10.0
# 3                 3          16.0
# 4                 6          35.0
#
# ...

# %%
weekly_patterns_NH.shape
# Out:
# (16471, 16)

# %%
# %ls
# Out:
# County_level_total.csv
# County_pop.csv
# Datathon.ipynb
# Datathon1.ipynb
# Safegraph-Starbucks-Demo - Databricks.html
# data_county_age_race.csv
# patterns_by_cty_week_industry.xlsx
# patterns_by_cty_week_industry_deaths.xlsx
# patterns_cty_week_overall_deaths_ses.xlsx
# safegraph_open_census_data/
# uscities.csv*
# uszips.csv*
# weekly-patterns-4-26-2020-CT.csv
# weekly-patterns-4-26-2020-NH.csv
# weekly-patterns-4-26-2020-RI.csv

# %%
patterns_by_city_industry = pd.read_excel('patterns_by_cty_week_industry.xlsx')

patterns_by_city_industry_deaths  = pd.read_excel('patterns_by_cty_week_industry_deaths.xlsx')
patterns_by_city_industrry_deaths_SES = pd.read_excel('patterns_cty_week_overall_deaths_ses.xlsx')

# %%
patterns_by_city_industry.head()
# Out:
#         date   county state  business_type  raw_visit_counts  median_dwell
# 0 2020-03-01  Bristol    RI  Entertainment              1646     54.137257
# 1 2020-03-01  Bristol    RI           Food              3620     71.675575
# 2 2020-03-01  Bristol    RI          Other              6810     89.912498
# 3 2020-03-01  Bristol    RI         Retail              4485     54.595238
# 4 2020-03-08  Bristol    RI  Entertainment              1558     52.807693

# %%
patterns_by_city_industry.shape
# Out:
# (468, 6)

# %%
patterns_by_city_industry_deaths.head()
# Out:
#         date     county state  business_type  raw_visit_counts  median_dwell  \
# 0 2020-03-08  Fairfield    CT  Entertainment             79134     50.666008
# 1 2020-03-08  Fairfield    CT           Food            120853     53.772430
# 2 2020-03-08  Fairfield    CT         Retail            157465     40.825397
# 3 2020-03-08  Fairfield    CT          Other            172322     98.531364
# 4 2020-03-15  Fairfield    CT          Other             90801    122.808876
#
#    cases  deaths       _merge
# 0     36       0  matched (3)
# 1     36       0  matched (3)
# 2     36       0  matched (3)
# 3     36       0  matched (3)
# 4    526      13  matched (3)

# %%
patterns_by_city_industry_deaths.shape
# Out:
# (312, 9)

# %%
patterns_by_city_industrry_deaths_SES.head()
# Out:
#         date      county state  visits  cases  deaths  median_dwell  \
# 0 2020-03-08   Fairfield    CT  529774    144       0     60.948799
# 1 2020-03-15   Fairfield    CT  307242   2104      52     77.483612
# 2 2020-03-15    Hartford    CT  219856    428       0     68.666962
# 3 2020-03-15  Litchfield    CT   41755    176       0     75.452026
# 4 2020-03-15   New Haven    CT  275147    388       0     68.566330
#
#    total_pop  households  female_pop  median_age  pop_65over  white_pop  \
# 0     944348      340491      484385        40.3      143419     588974
# 1     944348      340491      484385        40.3      143419     588974
# 2     894730      349064      460080        40.4      147260     553425
# 3     183031       73987       92584        47.2       36456     162898
# 4     859339      329857      445028        40.1      142411     546120
#
#    black_pop  asian_pop  hispanic_pop  amerindian_pop  other_race_pop  \
# ...

# %%
patterns_by_city_industrry_deaths_SES.shape
# Out:
# (78, 25)

# %%
data =  pd.Panel(patterns_by_city_industrry_deaths_SES)
# Out:
# /Users/garbamoussa/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-7e2e163f88b4> in <module>
# ----> 1 data =  pd.Panel(patterns_by_city_industrry_deaths_SES)
#
# TypeError: Panel() takes no arguments

# %%
# creating an empty panel
import pandas as pd
import numpy as np

data = np.random.rand(2,4,5)

# %%
dataflair_mul = pd.MultiIndex(levels=[['one', 'two'], ['a', 'b']], codes=[[1, 0, 1, 0], [1, 1, 0, 0]])
#dataflair_dat = pd.DataFrame({'S1': [2, 3, 4, 5], 'S2': [6, 7, 8, 9]}, index=dataflair_mul)

# %%
#multi_index = pd.MultiIndex(levels=[patterns_by_city_industrry_deaths_SES['county']], codes=[patterns_by_city_industrry_deaths_SES['date']])

patterns_by_city_industrry_deaths_SES.index.set_levels(patterns_by_city_industrry_deaths_SES.index.get_level_values('county').astype(int),
                    level='county', verify_integrity=False, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-8a9f6cfadb87> in <module>
#       1 #multi_index = pd.MultiIndex(levels=[patterns_by_city_industrry_deaths_SES['county']], codes=[patterns_by_city_industrry_deaths_SES['date']])
#       2
# ----> 3 patterns_by_city_industrry_deaths_SES.index.set_levels(patterns_by_city_industrry_deaths_SES.index.get_level_values('county').astype(int),
#       4                     level='county', verify_integrity=False, inplace=True)
#
# AttributeError: 'RangeIndex' object has no attribute 'set_levels'
